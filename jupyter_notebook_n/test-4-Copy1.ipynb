# %%
import sys
import importlib
import numpy as np
import h5py
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error
base_path = "../src/"
sys.path.append(base_path)
import models
import train
from losses import *

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#datafilename='../../DATA/data_L25LH_TNG.hdf5'
datafilename='../../DATA/data_L50_TNG_v3.hdf5'
with h5py.File(datafilename, 'r') as f:
    print("Datasets available:")
    for key in f.keys():
        print(key)

with h5py.File(datafilename, 'r') as f:
    #Parameters = f['Parameters'][0, :1024].T.reshape(-1, 1)
    Parameters = f['Parameters'][:, :1024].T
logflag = np.array([False, False, True, True, True, True, False, False, False, True, True, False, False, True, False, True, False, True, True, False, False, True, True, True, True, True, True, False, True, False, True, False, False, False, True])
logflag = logflag[:Parameters.shape[1]]
origParameters = Parameters
if not np.all(Parameters[:, logflag] > 0):
    raise ValueError("Some values to be logged are non-positive.")
PartiallyLoggedParameters = Parameters.copy()
PartiallyLoggedParameters[:, logflag] = np.log(PartiallyLoggedParameters[:, logflag])
means = PartiallyLoggedParameters.mean(axis=0)
stds = PartiallyLoggedParameters.std(axis=0)
Parameters = (PartiallyLoggedParameters - means) / stds

with h5py.File(datafilename, 'r') as f:
    Ms_Mh_s90 = f['Ms_Mh_s90'][:].T
    Ms_Mh_s61 = f['Ms_Mh_s61'][:].T
    MBH_Mh_s90 = f['MBH_Mh_s90'][:].T
    MBH_Mh_s61 = f['MBH_Mh_s61'][:].T
    Mg_Mh_s90 = f['Mg_Mh_s90'][:].T
    Mg_Mh_s61 = f['Mg_Mh_s61'][:].T
    Rs_Ms_s90 = f['Rs_Ms_s90'][:].T
    Rs_Ms_s61 = f['Rs_Ms_s61'][:].T
    SFR_Ms_s90 = f['SFR_Ms_s90'][:].T
    SFR_Ms_s61 = f['SFR_Ms_s61'][:].T
    Zs_Ms_s90 = f['Zs_Ms_s90'][:].T
    Zs_Ms_s61 = f['Zs_Ms_s61'][:].T
    SFRH_100Myr = f['SFRH_100Myr'][:].T
# Out:
# Datasets available:
# MBH_Mh_s61
# MBH_Mh_s90
# Mg_Mh_s61
# Mg_Mh_s90
# Ms_Mh_s61
# Ms_Mh_s90
# Parameters
# Rs_Ms_s61
# Rs_Ms_s90
# SFRH
# SFRH_100Myr
# SFRH_z
# SFR_Ms_s61
# SFR_Ms_s90
# Zs_Ms_s61
# Zs_Ms_s90
# logMh_s61
# logMh_s90
# logMs_s61
# logMs_s90

# %%
# choose which observables to include
#x = torch.from_numpy(Ms_Mh_s90).float()
#x = torch.cat((torch.from_numpy(Ms_Mh_s90), torch.from_numpy(Ms_Mh_s61)), dim=1).float()
#x = torch.cat((torch.from_numpy(Ms_Mh_s90), torch.from_numpy(Ms_Mh_s61), torch.from_numpy(MBH_Mh_s90), torch.from_numpy(MBH_Mh_s61), torch.from_numpy(Mg_Mh_s90), torch.from_numpy(Mg_Mh_s61)), dim=1).float()
x = torch.cat((torch.from_numpy(Ms_Mh_s90), torch.from_numpy(Ms_Mh_s61), torch.from_numpy(MBH_Mh_s90), torch.from_numpy(MBH_Mh_s61), torch.from_numpy(Mg_Mh_s90), torch.from_numpy(Mg_Mh_s61), torch.from_numpy(Rs_Ms_s90), torch.from_numpy(Rs_Ms_s61), torch.from_numpy(SFR_Ms_s90), torch.from_numpy(SFR_Ms_s61), torch.from_numpy(Zs_Ms_s90), torch.from_numpy(Zs_Ms_s61), torch.from_numpy(SFRH_100Myr)), dim=1).float()



normalized_data = True 

if normalized_data:
    x_np = x.numpy()
    x_means = x_np.mean(axis=0)
    x_stds = x_np.std(axis=0)
    x_np_norm = (x_np - x_means) / x_stds
    x = torch.from_numpy(x_np_norm).float()




print("Total NaNs:", torch.isnan(x).sum().item())
print("Total Infs:", torch.isinf(x).sum().item())
x[torch.isnan(x)] = 11
x[torch.isinf(x)] = 11
print("Total NaNs:", torch.isnan(x).sum().item())
print("Total Infs:", torch.isinf(x).sum().item())
y = torch.from_numpy(Parameters).float()
print(x.shape)
print(y.shape)
# Out:
# Total NaNs: 0
# Total Infs: 0
# Total NaNs: 0
# Total Infs: 0
# torch.Size([1024, 253])
# torch.Size([1024, 35])

# %%
# Hyperparameters
input_dim    = x.shape[1]
output_dim   = y.shape[1]
hidden_dims  = [128, 64]
#hidden_dims  = [128, 64, 64]
#hidden_dims  = [64, 64]
lr           = 1e-4
wd           = 1e-5
dropout_rate = 0.2
epochs       = 2000
val_fraction = 0.1
batch_size   = 64
separate_models = True

# %%
n_val = int(len(x) * val_fraction)
perm = torch.randperm(len(x))
idx_train = perm[:-n_val]
idx_val = perm[-n_val:]

x_train, y_train = x[idx_train], y[idx_train]
x_val, y_val = x[idx_val], y[idx_val]

# %%
importlib.reload(train)
importlib.reload(models)
# Out:
# <module 'models' from '/Users/nicolasgarcia/Downloads/GAL_SBI/camelsPE/jupyter_notebook/../src/models.py'>

# %%
# model, optimizer, loss function
criterion = MSELoss()
if separate_models and output_dim > 1:
    models_list = [models.SimpleMLP(input_dim, hidden_dims, 1, dropout_rate).to(device) for _ in range(output_dim)]
    optimizers = [optim.Adam(m.parameters(), lr=lr, weight_decay=wd) for m in models_list]
else:
    model = models.SimpleMLP(input_dim, hidden_dims, output_dim, dropout_rate).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=wd)

# %%
train_losses_list, val_losses_list = [], []
if separate_models and output_dim > 1:
    for i, (model_i, opt_i) in enumerate(zip(models_list, optimizers)):
        print(f"model #{i:d}")
        tl, vl = train.fit(
            model_i,
            DataLoader(TensorDataset(x_train, y_train[:, i:i+1]), batch_size=batch_size, shuffle=True),
            DataLoader(TensorDataset(x_val, y_val[:, i:i+1]), batch_size=batch_size, shuffle=False),
            opt_i, criterion, device, epochs)
        train_losses_list.append(tl)
        val_losses_list.append(vl)
    train_losses = np.mean(np.stack(train_losses_list), axis=0)
    val_losses = np.mean(np.stack(val_losses_list), axis=0)
else:
    train_loader = DataLoader(TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(TensorDataset(x_val, y_val), batch_size=batch_size, shuffle=False)
    train_losses, val_losses = train.fit(model, train_loader, val_loader, optimizer, criterion, device, epochs)
# Out:
# model #0
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.0238
# [Iter 1000] validation loss: 0.0253
# [Iter 1500] validation loss: 0.0271
# [Iter 2000] validation loss: 0.0240
# model #1
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.3420
# [Iter 1000] validation loss: 0.3399
# [Iter 1500] validation loss: 0.3281
# [Iter 2000] validation loss: 0.3055
# model #2
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.2521
# [Iter 1000] validation loss: 0.2633
# [Iter 1500] validation loss: 0.2751
# [Iter 2000] validation loss: 0.2749
# model #3
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 1.3604
# [Iter 1000] validation loss: 1.4197
# [Iter 1500] validation loss: 1.3649
# [Iter 2000] validation loss: 1.3828
# model #4
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.2811
# [Iter 1000] validation loss: 0.2928
# [Iter 1500] validation loss: 0.2960
# [Iter 2000] validation loss: 0.2919
# model #5
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 1.2199
# [Iter 1000] validation loss: 1.2200
# [Iter 1500] validation loss: 1.1747
# [Iter 2000] validation loss: 1.1562
# model #6
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.0299
# [Iter 1000] validation loss: 0.0302
# [Iter 1500] validation loss: 0.0336
# [Iter 2000] validation loss: 0.0401
# model #7
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.0531
# [Iter 1000] validation loss: 0.0543
# [Iter 1500] validation loss: 0.0556
# [Iter 2000] validation loss: 0.0530
# model #8
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.3071
# [Iter 1000] validation loss: 0.3050
# [Iter 1500] validation loss: 0.3133
# [Iter 2000] validation loss: 0.3029
# model #9
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.6048
# [Iter 1000] validation loss: 0.6319
# [Iter 1500] validation loss: 0.6508
# [Iter 2000] validation loss: 0.6369
# model #10
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 1.3105
# [Iter 1000] validation loss: 1.3514
# [Iter 1500] validation loss: 1.3135
# [Iter 2000] validation loss: 1.2828
# model #11
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.0581
# [Iter 1000] validation loss: 0.0584
# [Iter 1500] validation loss: 0.0587
# [Iter 2000] validation loss: 0.0607
# model #12
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.7135
# [Iter 1000] validation loss: 0.7360
# [Iter 1500] validation loss: 0.7215
# [Iter 2000] validation loss: 0.7732
# model #13
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 1.3005
# [Iter 1000] validation loss: 1.3720
# [Iter 1500] validation loss: 1.3336
# [Iter 2000] validation loss: 1.3157
# model #14
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.7271
# [Iter 1000] validation loss: 0.7533
# [Iter 1500] validation loss: 0.7730
# [Iter 2000] validation loss: 0.7557
# model #15
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.3392
# [Iter 1000] validation loss: 0.3220
# [Iter 1500] validation loss: 0.3242
# [Iter 2000] validation loss: 0.3418
# model #16
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.3846
# [Iter 1000] validation loss: 0.3771
# [Iter 1500] validation loss: 0.3760
# [Iter 2000] validation loss: 0.3952
# model #17
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.6061
# [Iter 1000] validation loss: 0.6171
# [Iter 1500] validation loss: 0.6448
# [Iter 2000] validation loss: 0.6378
# model #18
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 1.0423
# [Iter 1000] validation loss: 0.9825
# [Iter 1500] validation loss: 0.8875
# [Iter 2000] validation loss: 0.8561
# model #19
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 1.1175
# [Iter 1000] validation loss: 1.2215
# [Iter 1500] validation loss: 1.1898
# [Iter 2000] validation loss: 1.2218
# model #20
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.4183
# [Iter 1000] validation loss: 0.4249
# [Iter 1500] validation loss: 0.4159
# [Iter 2000] validation loss: 0.4337
# model #21
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.9978
# [Iter 1000] validation loss: 0.9905
# [Iter 1500] validation loss: 0.9048
# [Iter 2000] validation loss: 0.8723
# model #22
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 1.0111
# [Iter 1000] validation loss: 1.0878
# [Iter 1500] validation loss: 1.1019
# [Iter 2000] validation loss: 1.0770
# model #23
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 1.0808
# [Iter 1000] validation loss: 1.1096
# [Iter 1500] validation loss: 1.0528
# [Iter 2000] validation loss: 1.0194
# model #24
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.7794
# [Iter 1000] validation loss: 0.7449
# [Iter 1500] validation loss: 0.7059
# [Iter 2000] validation loss: 0.6819
# model #25
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.6602
# [Iter 1000] validation loss: 0.6937
# [Iter 1500] validation loss: 0.6933
# [Iter 2000] validation loss: 0.6883
# model #26
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.7179
# [Iter 1000] validation loss: 0.7051
# [Iter 1500] validation loss: 0.6803
# [Iter 2000] validation loss: 0.6903
# model #27
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.8379
# [Iter 1000] validation loss: 0.8189
# [Iter 1500] validation loss: 0.8157
# [Iter 2000] validation loss: 0.7981
# model #28
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.4824
# [Iter 1000] validation loss: 0.4996
# [Iter 1500] validation loss: 0.5134
# [Iter 2000] validation loss: 0.5157
# model #29
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 1.3791
# [Iter 1000] validation loss: 1.3568
# [Iter 1500] validation loss: 1.2560
# [Iter 2000] validation loss: 1.2424
# model #30
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 1.2211
# [Iter 1000] validation loss: 1.2898
# [Iter 1500] validation loss: 1.2875
# [Iter 2000] validation loss: 1.2691
# model #31
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 1.1259
# [Iter 1000] validation loss: 1.1517
# [Iter 1500] validation loss: 1.1244
# [Iter 2000] validation loss: 1.1098
# model #32
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 1.3583
# [Iter 1000] validation loss: 1.3905
# [Iter 1500] validation loss: 1.3933
# [Iter 2000] validation loss: 1.4063
# model #33
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 1.2243
# [Iter 1000] validation loss: 1.3062
# [Iter 1500] validation loss: 1.3518
# [Iter 2000] validation loss: 1.3243
# model #34
# Training:   0%|          | 0/2000 [00:00<?, ?iter/s]
# [Iter  500] validation loss: 0.3198
# [Iter 1000] validation loss: 0.2667
# [Iter 1500] validation loss: 0.2440
# [Iter 2000] validation loss: 0.2572

# %%
plt.figure(figsize=(10, 6))
epochs_range = range(1, epochs + 1)
plt.plot(epochs_range, train_losses, label='Training Loss')
plt.plot(epochs_range, val_losses, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
#plt.savefig("../../../plots/training_plot.png")
plt.show()

# %%
if separate_models and output_dim > 1:
    with torch.no_grad():
        preds_list = [m(x_val.to(device)).cpu() for m in models_list]
    all_predictions = torch.cat(preds_list, dim=1).numpy()
    all_true_values = y_val.numpy()
else:
    model.eval()
    predictions, true_values = [], []
    
    with torch.no_grad():
        for xb, yb in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            preds = model(xb)       
            predictions.append(preds.cpu())
            true_values.append(yb.cpu())
            
    all_predictions = torch.cat(predictions).numpy()
    all_true_values = torch.cat(true_values).numpy()

all_predictions = all_predictions * stds + means
all_true_values = all_true_values * stds + means
all_predictions[:, logflag] = np.exp(all_predictions[:, logflag])
all_true_values[:, logflag] = np.exp(all_true_values[:, logflag])

# %%
n_cols = int(np.floor(np.sqrt(output_dim)))
n_rows = int(np.ceil(output_dim / n_cols))
fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 5 * n_rows))
axes = np.atleast_1d(axes).reshape(n_rows, n_cols)
for i in range(output_dim):
    ax = axes.flat[i]
    predictions = all_predictions[:, i]
    true_values = all_true_values[:, i]
    ax.scatter(true_values, predictions, alpha=0.6)
    r2 = r2_score(true_values, predictions)
    rmse = np.sqrt(mean_squared_error(true_values, predictions))
    min_val = min(true_values.min(), predictions.min())
    max_val = max(true_values.max(), predictions.max())
    ax.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2)
    ax.set_xlabel('True Values')
    ax.set_ylabel('Predicted Values')
    ax.set_title(f'R\u00b2 = {r2:.3f}, RMSE = {rmse:.3f}')
    ax.grid(True)
    span = max_val - min_val
    ax.set_xlim(min_val - 0.1 * span, max_val + 0.1 * span)
    ax.set_ylim(min_val - 0.1 * span, max_val + 0.1 * span)
for j in range(output_dim, n_rows * n_cols):
    fig.delaxes(axes.flat[j])
fig.tight_layout()
#fig.savefig('../../../plots/results_plot.png')
plt.show()
